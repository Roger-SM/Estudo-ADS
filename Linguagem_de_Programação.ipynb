# %% [markdown]
# <a href="https://colab.research.google.com/github/Roger-SM/Estudo-ADS/blob/main/Linguagem_de_Programa%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #U1 - A1

# %%
#1. Nosso Primeiro Programa:

print("Hello World")
# Out:
# Hello World

# %%
#2. Criando variaveis de tipos diferentes:
x = 10
nome = 'Roger'
nota = 8.75
fez_inscricao = True

# %%
#3. Mostrando as variaveis:
print(x)
print(nome)
print(nota)
print(fez_inscricao)
# Out:
# 10
# Roger
# 8.75
# True

# %%
#4. Mostrando os tipos das variaveis:
print(type(x))
print(type(nome))
print(type(nota))
print(type(fez_inscricao))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
#5. Nova função "Input":
input('Digite seu nome>')
# Out:
# Digite seu nome>Roger
# 'Roger'

# %%
#6. Melhorando a linha de codigo:

print(f'Olá, {nome}, bem vindo à disciplina de programação!')
# Out:
# Olá, Roger, bem vindo à disciplina de programação!

# %%
#7. Começando a idealizar um programa:
nota_1 = int(input('DIGITE SUA NOTA: '))
nota_2 = int(input('DIGITE SUA NOTA: '))
nota_3 = int(input('DIGITE SUA NOTA: '))
nota_4 = int(input('DIGITE SUA NOTA: '))
# Out:
# DIGITE SUA NOTA: 9
# DIGITE SUA NOTA: 7
# DIGITE SUA NOTA: 5
# DIGITE SUA NOTA: 8

# %%
#8. Vamos calcular a media:
media = (nota_1+nota_2+nota_3+nota_4)/4
print(media)
# Out:
# 7.25

# %%
#9. Criando variaveis:
if media >= 6:
  situacao = 'APROVADO'
else:
  situacao = 'REPROVADO'
print(situacao)
# Out:
# APROVADO

# %%
#10. Agora sim! Aprendendo coisas novas. Para isso vamos criar algo diferente. Um "Hello World" mais completo kkk:

nome = input("Olá, Digite seu nome: ")

print(f"Olá {nome}, seja bem vindo! ")
# Out:
# Olá, Digite seu nome: Junior
# Olá Junior, seja bem vindo!
